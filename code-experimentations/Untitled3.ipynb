# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.argv[1] = 1

# %%
dataset = generate_monotone_consistent_dataset(500, 2)
plot2DSet(dataset, "")

# %%
dataset = add_noise(dataset, 0.5)
plot2DSet(dataset, "")

# %%
np.count_nonzero(dataset.y == 2)
# Out:
# 248
