# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#%matplotlib inline
# %matplotlib notebook

# %%
import pickle

# %%
noises = np.arange(0, 0.55, 0.025) * 100
noises
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ,
#        27.5, 30. , 32.5, 35. , 37.5, 40. , 42.5, 45. , 47.5, 50. , 52.5])

# %%
acc1 = []
acc2 = []
# acc3 = []
# acc4 = []
# acc5 = []
# acc6 = []

for i in range(22):
    f = open("k7acc/k7acc1_" + str(i), "rb")
    acc1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7acc/k7acc2_" + str(i), "rb")
    acc2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("acc5/acc5_3_" + str(i), "rb")
#     acc3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("acc5/acc5_4_" + str(i), "rb")
#     acc4.append(pickle.load(f))
#     f.close()
#for i in range(11):
#    f = open("acc5/acc5_5_" + str(i), "rb")
#    acc5.append(pickle.load(f))
#    f.close()
# for i in range(11):
#     f= open("acc5/acc5_6_" + str(i), "rb")
#     acc6.append(pickle.load(f))
#     f.close()    
    
acc1 = np.array(acc1)
acc2 = np.array(acc2)
# acc3 = np.array(acc3)
# acc4 = np.array(acc4)
#acc5 = np.array(acc5)
# acc6 = np.array(acc6)

# %%
depth1 = []
depth2 = []
# depth3 = []
# depth4 = []
#depth5 = []
#depth6 = []

for i in range(22):
    f = open("k7depth/k7depth1_" + str(i), "rb")
    depth1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7depth/k7depth2_" + str(i), "rb")
    depth2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("depth3/depth3_3_" + str(i), "rb")
#     depth3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("depth3/depth3_4_" + str(i), "rb")
#     depth4.append(pickle.load(f))
#     f.close()
#for i in range(11):
#    f = open("depth3/depth3_5_" + str(i), "rb")
#    depth5.append(pickle.load(f))
#    f.close()
#for i in range(11):
#    f = open("depth3/depth3_6_" + str(i), "rb")
#    depth6.append(pickle.load(f))
#    f.close()
    
depth1 = np.array(depth1)
depth2 = np.array(depth2)
# depth3 = np.array(depth3)
# depth4 = np.array(depth4)
#depth5 = np.array(depth5)
#depth6 = np.array(depth6)

# %%
leaves1 = []
leaves2 = []
# leaves3 = []
# leaves4 = []
# leaves5 = []
# leaves6 = []

for i in range(22):
    f = open("k7leaves/k7leaves1_" + str(i), "rb")
    leaves1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7leaves/k7leaves2_" + str(i), "rb")
    leaves2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("leaves3/leaves3_3_" + str(i), "rb")
#     leaves3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("leaves3/leaves3_4_" + str(i), "rb")
#     leaves4.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("leaves3/leaves3_5_" + str(i), "rb")
#     leaves5.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("leaves3/leaves3_6_" + str(i), "rb")
#     leaves6.append(pickle.load(f))
#     f.close()
    
leaves1 = np.array(leaves1)
leaves2 = np.array(leaves2)
# leaves3 = np.array(leaves3)
# leaves4 = np.array(leaves4)
# leaves5 = np.array(leaves5)
# leaves6 = np.array(leaves6)

# %%
ratio1 = []
ratio2 = []
# ratio3 = []
# ratio4 = []
# # ratio5 = []
# ratio6 = []

for i in range(22):
    f = open("k7ratio/k7ratio1_" + str(i), "rb")
    ratio1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7ratio/k7ratio2_" + str(i), "rb")
    ratio2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("ratio5/ratio5_3_" + str(i), "rb")
#     ratio3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("ratio5/ratio5_4_" + str(i), "rb")
#     ratio4.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("ratio3/ratio3_5_" + str(i), "rb")
#     ratio5.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("ratio5/ratio5_6_" + str(i), "rb")
#     ratio6.append(pickle.load(f))
#     f.close()
    
ratio1 = np.array(ratio1)
ratio2 = np.array(ratio2)
# ratio3 = np.array(ratio3)
# ratio4 = np.array(ratio4)
# # ratio5 = np.array(ratio5)
# ratio6 = np.array(ratio6)

# %%
pairs1 = []
pairs2 = []
# pairs3 = []
# pairs4 = []
# pairs5 = []
# pairs6 = []

for i in range(22):
    f = open("k7pairs/k7pairs1_" + str(i), "rb")
    pairs1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7pairs/k7pairs2_" + str(i), "rb")
    pairs2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("pairs/pairs3_" + str(i), "rb")
#     pairs3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("pairs/pairs4_" + str(i), "rb")
#     pairs4.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("pairs/pairs5_" + str(i), "rb")
#     pairs5.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("pairs/pairs6_" + str(i), "rb")
#     pairs6.append(pickle.load(f))
#     f.close()    
    
pairs1 = np.array(pairs1)
pairs2 = np.array(pairs2)
# pairs3 = np.array(pairs3)
# pairs4 = np.array(pairs4)
# pairs5 = np.array(pairs5)
# pairs6 = np.array(pairs6)

# %%
nb_examples1 = []
nb_examples2 = []
# nb_examples3 = []
# nb_examples4 = []
# nb_examples6 = []

for i in range(22):
    f = open("k7examples/k7examples1_" + str(i), "rb")
    nb_examples1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7examples/k7examples2_" + str(i), "rb")
    nb_examples2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("nb_examples/nb_examples3_" + str(i), "rb")
#     nb_examples3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("nb_examples/nb_examples4_" + str(i), "rb")
#     nb_examples4.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("nb_examples/nb_examples6_" + str(i), "rb")
#     nb_examples6.append(pickle.load(f))
#     f.close()
    
nb_examples1 = np.array(nb_examples1)
nb_examples2 = np.array(nb_examples2)
# nb_examples3 = np.array(nb_examples3)
# nb_examples4 = np.array(nb_examples4)
# nb_examples6 = np.array(nb_examples6)

# %%
pairs1 = []
pairs2 = []
# pairs3 = []
# pairs4 = []
# pairs5 = []
# pairs6 = []

for i in range(22):
    f = open("k7pairs/k7pairs1_" + str(i), "rb")
    pairs1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7pairs/k7pairs2_" + str(i), "rb")
    pairs2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("pairs/pairs3_" + str(i), "rb")
#     pairs3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("pairs/pairs4_" + str(i), "rb")
#     pairs4.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("pairs/pairs5_" + str(i), "rb")
#     pairs5.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("pairs/pairs6_" + str(i), "rb")
#     pairs6.append(pickle.load(f))
#     f.close()    
    
pairs1 = np.array(pairs1)
pairs2 = np.array(pairs2)
# pairs3 = np.array(pairs3)
# pairs4 = np.array(pairs4)
# pairs5 = np.array(pairs5)
# pairs6 = np.array(pairs6)

# %%
eval1 = []
eval2 = []
# eval3 = []
# eval4 = []

for i in range(22):
    f = open("k7eval/k7eval1_" + str(i), "rb")
    eval1.append(pickle.load(f))
    f.close()
for i in range(22):
    f = open("k7eval/k7eval2_" + str(i), "rb")
    eval2.append(pickle.load(f))
    f.close()
# for i in range(11):
#     f = open("eval3/eval3_3_" + str(i), "rb")
#     eval3.append(pickle.load(f))
#     f.close()
# for i in range(11):
#     f = open("eval3/eval3_4_" + str(i), "rb")
#     eval4.append(pickle.load(f))
#     f.close()
    
eval1 = np.array(eval1)
eval2 = np.array(eval2)
# eval3 = np.array(eval3)
# eval4 = np.array(eval4)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, acc1 * 100, label="rank Shannon discrimination measure tree")
ax.plot(noises, acc2 * 100, label="Shannon entropy tree")
# ax.plot(noises, acc3 * 100, label="rank Gini discrimination measure tree")
# ax.plot(noises, acc4 * 100, label="Gini entropy tree")
# ax.plot(noises, acc5 * 100, label="pessimistic rank discrimination tree")
# ax.plot(noises, acc6 * 100, label="H_M")
ax.set_xlabel("noise %")
ax.set_ylabel("average correctly classified instances %")
ax.set_title("average correctly classified instances % depending on noise %")
ax.legend()
fig.tight_layout()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, depth1, label="rank shannon discrimination measure")
ax.plot(noises, depth2, label="Shannon entropy tree")
# ax.plot(noises, depth3, label="rank Gini discrimination measure tree")
# ax.plot(noises, depth4, label="Gini entropy tree")
# ax.plot(noises, depth5, label="pessimistic rank discrimination tree")
# ax.plot(noises, depth6, label="H_M")
ax.set_xlabel("noise %")
ax.set_ylabel("average tree depth")
ax.set_title("average tree depth depending on noise %")
ax.legend()
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, leaves1, label="rank shannon discrimination measure")
ax.plot(noises, leaves2, label="Shannon entropy tree")
# ax.plot(noises, leaves3, label="rank Gini discrimination measure tree")
# ax.plot(noises, leaves4, label="Gini entropy tree")
# ax.plot(noises, leaves5, label="pessimistic rank discrimination tree")
# ax.plot(noises, leaves6, label="H_M tree")
ax.set_xlabel("noise %")
ax.set_ylabel("average number of leaves")
ax.set_title("average number of leaves depending on noise %")
ax.legend()
fig.tight_layout()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, ratio1, label="rank shannon discrimination measure")
ax.plot(noises, ratio2, label="Shannon entropy tree")
# ax.plot(noises, ratio3, label="rank Gini discrimination measure tree")
# ax.plot(noises, ratio4, label="Gini entropy tree")
# ax.plot(noises, ratio5, label="pessimistic rank discrimination tree")
# ax.plot(noises, ratio6, label="H_M tree")
ax.set_xlabel("noise %")
ax.set_ylabel("average ratio")
ax.set_title("average ratio depending on noise %")
ax.legend()
fig.tight_layout()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, pairs1, label="rank shannon discrimination measure tree")
ax.plot(noises, pairs2, label="Shannon entropy tree")
# ax.plot(noises, pairs3, label="rank Gini discrimination measure tree")
# ax.plot(noises, pairs4, label="Gini entropy tree")
# ax.plot(noises, pairs5, label="pessimistic rank discrimination tree")
# ax.plot(noises, pairs6, label="H_M tree")
ax.set_xlabel("noise %")
ax.set_ylabel("total number of pairs used for ratio computing")
ax.set_title("total number of pairs used for ratio computing depending on noise %")
ax.legend()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, nb_examples1, label="rank shannon discrimination measure tree")
ax.plot(noises, nb_examples2, label="Shannon entropy tree")
# ax.plot(noises, nb_examples3, label="rank Gini discrimination measure tree")
# ax.plot(noises, nb_examples4, label="Gini entropy tree")
# ax.plot(noises, nb_examples6, label="H_M tree")
ax.set_xlabel("noise %")
ax.set_ylabel("total number of examples used for ratio computing")
ax.set_title("total number of examples used for ratio computing depending on noise %")
ax.legend()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, eval1, label="rank shannon discrimination measure tree")
ax.plot(noises, eval2, label="Shannon entropy tree")
# ax.plot(noises, eval3, label="rank Gini discrimination measure tree")
# ax.plot(noises, eval4, label="Gini entropy tree")
# ax.plot(noises, eval6, label="H_m tree")
ax.set_xlabel("noise %")
ax.set_ylabel("Average rank Shannon evaluation")
ax.set_title("average rank Shannon evaluation depending on noise %")
ax.legend()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 
ax.plot(noises, p_ratio1, label="rank shannon discrimination measure tree")
ax.plot(noises, p_ratio2, label="Shannon entropy tree")
ax.plot(noises, p_ratio3, label="rank Gini discrimination measure tree")
ax.plot(noises, p_ratio4, label="Gini entropy tree")
ax.plot(noises, p_ratio6, label="H_m tree")
ax.set_xlabel("noise %")
ax.set_ylabel("Average ratio between number of pairs and number of nodes")
ax.set_title("average pair ratio depending on noise %")
ax.legend()
fig.show()
